# %% [markdown]
# # 12. 다음을 프로그래밍 하세요.

# %% [markdown]
# ## 학생의 이름은 A, B, C, D 입니다.
#
# ## 각 학생의 수학점수는 55, 70, 93, 68 입니다.
#
# ## 이 데이터들을 scores 라는 변수 이름으로 저장하세요.

# %% [markdown]
# # 13. 유저한테 학생 이름을 입력받으면, 해당 학생의 점수를 출력하세요.
#
# - 예) B를 입력하면, 70 이 출력됩니다.

# %% [markdown]
# # 14. 수학 점수의 평균을 출력하세요.

# %% [markdown]
# # 15. 학생의 이름을, 한번에 모두 출력하세요.

# %% [markdown]
# # 16. 유저한테 새로운 학생의 이름과 점수를 입력받아서, scores 에 추가합니다.
#
# - 입력 ) 학생이름 입력 :
#        점수 입력 :

# %% [markdown]
# # 17. scores에 저장된 수학점수의 평균을 구하세요.

# %% [markdown]
# # 18. C 학생이 전학을 갔습니다. C학생의 데이터를 없애세요.

# %% [markdown]
# # 19. B 학생의 점수를 99 점으로 바꾸세요.

# %% [markdown]
# #  20. 09/07의 종가를 리스트의 첫 번째 항목으로 입력해서 naver_closing_price라는 이름의 리스트를 만들어보세요.

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-07-13%2021.32.16.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-07-13%2021.32.16.png)

# %% [markdown]
# # 21. 리스트의 최대값과 최소값을 구하세요.
# ### hint : max( ) 함수,  min( ) 함수 이용
